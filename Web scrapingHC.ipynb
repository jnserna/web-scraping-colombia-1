# %%
from urllib.request import urlopen
from urllib.request import Request
from bs4 import BeautifulSoup as soup
import requests
import numpy as np

buscar = str(input("Producto a buscar: "))

columnas = "descripcion, marca, precio final, precio normal, precio final CMR, precio normal CMR, precio final Internet, precio normal Internet, unidad, enlace\n"
filename = "web-scraping-Homecenter-" + buscar + ".csv"
f = open(filename, "w", encoding="utf-8")
f.write(columnas)

user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
headers={'User-Agent':user_agent,} 

my_url = 'https://www.homecenter.com.co/homecenter-co/search/?Ntt=' + buscar
my_url=requests.get(my_url).url
request=Request(my_url,None,headers) 
response = urlopen(request)
page_html = response.read().decode(encoding="iso-8859-1")
response.close()
page_soup = soup(page_html, "html.parser")
p = page_soup.findAll("ul",{"class":"jsx-4278284191 page-indicies"})
if p != [] :
    lenp=len(p[0])
    pages = np.arange(1, lenp+1, 1)
else: 
    pages = np.arange(1, 2, 1)

CRED = '\33[34m'
CEND = '\33[0m'
if p != []:
    print (CRED+"Extrayendo... \n" + "{} Pagina(s) \n".format(lenp)+CEND)
else:
    print (CRED+"Extrayendo... \n" + "1 Pagina \n" + CEND)
    
for page in pages:
    
    my_url = 'https://www.homecenter.com.co/homecenter-co/search/?Ntt=' + buscar
    my_url=requests.get(my_url).url + "&currentpage=" + str(page)

    request=Request(my_url,None,headers) 
    response = urlopen(request)
    page_html = response.read().decode(encoding="iso-8859-1")
    response.close()

    # html parsing
    page_soup = soup(page_html, "html.parser")

    # grabs each product
    containers = page_soup.findAll("div",{"class":"jsx-411745769 product ie11-product-container"})

    print(CRED+"Extrayendo... \n"+ "Pagina {}, {} productos \n".format(str(page),len(containers))+CEND)

    for container in containers: 

        descripcion = container.findAll("h2",{"class":"jsx-411745769 product-title"})
        descripcion = descripcion[0].text.replace(",","")

        marca = container.findAll("div",{"class":"jsx-411745769 product-brand"})
        if len(marca) !=0:
            marca = marca[0].text
        else:
            marca=""

        precio_fin = container.findAll("div",{"class":"jsx-585964327 main gridView"})
        if len(precio_fin) != 0:
            precio_fin = precio_fin[0].text
        else:
            precio_fin = ""

        precio_full = container.findAll("div",{"class":"jsx-585964327 sub gridView"})
        if len(precio_full) !=0:
            precio_full = precio_full[0].text.replace("Normal:","")
        else:
            precio_full = ""

        precio_fin_CMR = container.findAll("div",{"class":"jsx-585964327 main gridView CMR"})
        if len(precio_fin_CMR) != 0:
            precio_fin_CMR = precio_fin_CMR[0].text
        else:
            precio_fin_CMR = ""

        precio_full_CMR = container.findAll("div",{"class":"jsx-585964327 sub gridView CMR"})
        if len(precio_full_CMR) !=0:
            precio_full_CMR = precio_full_CMR[0].text.replace("Normal:","")
        else:
            precio_full_CMR = ""
            
        precio_fin_int = container.findAll("div",{"class":"jsx-585964327 main gridView INTERNET"})
        if len(precio_fin_int) != 0:
            precio_fin_int = precio_fin_int[0].text
        else:
            precio_fin_int = ""

        precio_full_int = container.findAll("div",{"class":"jsx-585964327 sub gridView INTERNET"})
        if len(precio_full_int) !=0:
            precio_full_int = precio_full_int[0].text.replace("Normal:","")
        else:
            precio_full_int = ""


        unidad = container.findAll("span",{"class":"jsx-4135487716 price-unit"})
        if len(unidad) != 0:
            unidad = unidad[0].text
        else: unidad=""

        enlace = "https://www.homecenter.com.co"+container.a["href"]

        print("descripcion: " + descripcion)
        print("marca: " + marca)
        print("precio final: " + precio_fin)
        print("precio normal: " + precio_full)
        print("precio final CMR: " + precio_fin_CMR)
        print("precio normal CMR: " + precio_full_CMR)
        print("precio final internet " + precio_fin_int)
        print("precio normal internet: " + precio_full_int)
        print("unidad: " + unidad)
        print("enlace: " + enlace + "\n")    

        
        f.write(descripcion + "," + marca + "," + precio_fin + "," + precio_full + "," + precio_fin_CMR + "," + precio_full_CMR + ',' + precio_fin_int + "," + precio_full_int+ "," +  unidad + "," + enlace + "\n")

f.close()
# Out:
# Producto a buscar:  taladro
# Extrayendo...
# 5 Pagina(s)
#
# Extrayendo...
# Pagina 1, 28 productos
#
# descripcion: Taladro Atornillador 12V inalÃ¡mbrico 3/8? + Accesorios +  Estuche
# marca: BLACK+DECKER
# precio final: $129.900UND
# precio normal: $199.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/389244/Taladro-Atornillador-12V-inalambrico-3-8-Accesorios-Estuche/389244
#
# descripcion: Taladro Percutor 3/8 Pulgada 600 W 3000 Rpm Vvr
# marca: Bauker
# precio final: $89.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/315726/Taladro-Percutor-3-8-Pulgada-600-W-3000-Rpm-Vvr/315726
#
# descripcion: Kit Taladro Percutor 3/8-pulg 12V 1.3Ah I-L + 29 Accesorios
# marca: Bauker
# precio final:
# precio normal:
# precio final CMR: $149.900UND
# precio normal CMR: $239.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/402014/Kit-Taladro-Percutor-3-8-pulg-12V-13Ah-I-L-29-Accesorios/402014
#
# descripcion: Kit Taladro Percutor 1/2-pulg 550W 2800RPM + 40 Accesorios Black+Decker
# marca: BLACK+DECKER
# precio final: $189.900UND
# precio normal: $248.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/308708/Kit-Taladro-Percutor-1-2-pulg-550W-2800RPM-40-Accesorios-BlackDecker/308708
#
# descripcion: Combo Taladro Percutor 3/8 pulg TB550 + Atornillador InalÃ¡mbrico 3.6V 9036 Black+Decker
# marca: BLACK+DECKER
# precio final: $154.900UND
# precio normal: $174.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/355597/Combo-Taladro-Percutor-3-8-pulg-TB550-Atornillador-Inalambrico-36V-9036-BlackDecker/355597
#
# descripcion: Kit Taladro Percutor InalÃ¡mbrico 1/2-pulg 21V Con 2 Baterias y 1 Cargador Furius
# marca: FURIUS
# precio final: $259.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/489488/Kit-Taladro-Percutor-Inalambrico-1-2-pulg-21V-Con-2-Baterias-y-1-Cargador-Furius/489488
#
# descripcion: Kit Taladro Percutor 3/8-pulg 600W 3000RPM VVR + 90 Accesorios
# marca: Bauker
# precio final: $179.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/313122/Kit-Taladro-Percutor-3-8-pulg-600W-3000RPM-VVR-90-Accesorios/313122
#
# descripcion: Taladro InalÃ¡mbrico RotaciÃ³n 3/8-pulg 20V I-L Black+Decker
# marca: BLACK+DECKER
# precio final: $189.900UND
# precio normal: $299.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/497588/Taladro-Inalambrico-Rotacion-3-8-pulg-20V-I-L-BlackDecker/497588
#
# descripcion: Kit Taladro Percutor 1/2-pulg 750W + 48 Accesorios
# marca: Bauker
# precio final: $199.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/215461/Kit-Taladro-Percutor-1-2-pulg-750W-48-Accesorios/215461
#
# descripcion: Kit Taladro Percutor 1/2-pulg 550W + MaletÃ­n PlÃ¡stico Bosch
# marca: Bosch
# precio final: $164.900UND
# precio normal: $239.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/440155/Kit-Taladro-Percutor-1-2-pulg-550W-Maletin-Plastico-Bosch/440155
#
# descripcion: Kit Taladro Percutor InalÃ¡mbrico 3/8-pulg 12V con BaterÃ­a Incluida + 75 Accesorios Makita
# marca: Makita
# precio final: $379.900UND
# precio normal: $439.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/512272/Kit-Taladro-Percutor-Inalambrico-3-8-pulg-12V-con-Bateria-Incluida-75-Accesorios-Makita/512272
#
# descripcion: Combo Taladro Percutor 1/2-pulg 750W + Pulidora 4-1/2 820W
# marca: Bauker
# precio final: $259.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/298775/Combo-Taladro-Percutor-1-2-pulg-750W-Pulidora-4-1-2-820W/298775
#
# descripcion: Taladro Percutor  3/8 De Pulgada 550W 2900Rpm 1V
# marca: BLACK+DECKER
# precio final: $107.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/239580/Taladro-Percutor-3-8-De-Pulgada-550W-2900Rpm-1V/239580
#
# descripcion: Kit Taladro Percutor 1/2-pulg 600W 0-3'000rpm Velocidad Variable Reversible + 9 Accesorios
# marca: Bauker
# precio final:
# precio normal:
# precio final CMR: $149.900UND
# precio normal CMR: $164.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/315728/Kit-Taladro-Percutor-1-2-pulg-600W-0-3000rpm-Velocidad-Variable-Reversible-9-Accesorios/315728
#
# descripcion: Kit Taladro Percutor 1/2-pulg 600W + Pulidora 4-1/2 pulg 820W + 17 Accesorios Bauker
# marca: Bauker
# precio final:
# precio normal:
# precio final CMR: $199.900UND
# precio normal CMR: $229.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/315729/Kit-Taladro-Percutor-1-2-pulg-600W-Pulidora-4-1-2-pulg-820W-17-Accesorios-Bauker/315729
#
# descripcion: Taladro InalÃ¡mbrico Atornillador/Percutor 1/2-pulg 20V Incluye Cargador Dewalt
# marca: Dewalt
# precio final: $399.900UND
# precio normal: $599.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/301039/Taladro-Inalambrico-Atornillador-Percutor-1-2-pulg-20V-Incluye-Cargador-Dewalt/301039
#
# descripcion: Kit Taladro RotaciÃ³n 3/8-pulg 12V 1.3Ah I-L VVRx2 + 13 Accesorios
# marca: Bauker
# precio final:
# precio normal:
# precio final CMR: $179.900UND
# precio normal CMR: $199.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/268821/Kit-Taladro-Rotacion-3-8-pulg-12V-13Ah-I-L-VVRx2-13-Accesorios/268821
#
# descripcion: Taladro Percutor 1/2-pulg 770w 2800rpm
# marca: Dewalt
# precio final:
# precio normal:
# precio final CMR: $259.900UND
# precio normal CMR: $289.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/337440/Taladro-Percutor-1-2-pulg-770w-2800rpm/337440
#
# descripcion: Taladro Percutor 1/2 pulgada 550W 2800rpm ID550KC
# marca: KARSON
# precio final: $79.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/99563/Taladro-Percutor-1-2-pulgada-550W-2800rpm-ID550KC/99563
#
# descripcion: Taladro Percutor Atornillador InalÃ¡mbrico 3/8Pulg 12V
# marca: BLACK&WHITE
# precio final: $169.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/509932/Taladro-Percutor-Atornillador-Inalambrico-3-8Pulg-12V/509932
#
# descripcion: Kit Taladro Percutor 1/2-pulg 550W 2800RPM + 88 Accesorios
# marca: BLACK+DECKER
# precio final:
# precio normal:
# precio final CMR: $199.900UND
# precio normal CMR: $219.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/315872/Kit-Taladro-Percutor-1-2-pulg-550W-2800RPM-88-Accesorios/315872
#
# descripcion: Taladro RotaciÃ³n InalÃ¡mbrico 3/8-pulg 12V Black+Decker
# marca: BLACK+DECKER
# precio final: $169.900UND
# precio normal: $249.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/872098/Taladro-Rotacion-Inalambrico-3-8-pulg-12V-BlackDecker/872098
#
# descripcion: Combo Taladro Percutor 1/2-pulg 600W + Pulidora 4.1/2-pulg 850W 11000Rpm Stanley
# marca: Stanley
# precio final:
# precio normal:
# precio final CMR: $349.900UND
# precio normal CMR: $399.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/314246/Combo-Taladro-Percutor-1-2-pulg-600W-Pulidora-41-2-pulg-850W-11000Rpm-Stanley/314246
#
# descripcion: Taladro 1/2 Percutor 550W 2800 Rpm Vvr
# marca: BLACK+DECKER
# precio final: $172.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/296233/Taladro-1-2-Percutor-550W-2800-Rpm-Vvr/296233
#
# descripcion: Taladro Percutor 1/2-pulg 650W 3150RPM 47250GPM
# marca: Bosch
# precio final: $244.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/289510/Taladro-Percutor-1-2-pulg-650W-3150RPM-47250GPM/289510
#
# descripcion: Taladro RotaciÃ³n 3/8-pulg 8V I-L
# marca: BLACK+DECKER
# precio final: $161.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/327881/Taladro-Rotacion-3-8-pulg-8V-I-L/327881
#
# descripcion: Taladro 3/8Pg Percutor + Atornillador Impacto 12V Makita
# marca: Makita
# precio final:
# precio normal:
# precio final CMR: $649.900UND
# precio normal CMR: $699.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/521778/Taladro-3-8Pg-Percutor-Atornillador-Impacto-12V-Makita/521778
#
# descripcion: Taladro Percutor 3/8 de pulgada 500W 2800rpm ID500K1
# marca: KARSON
# precio final: $69.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/99564/Taladro-Percutor-3-8-de-pulgada-500W-2800rpm-ID500K1/99564
#
# Extrayendo...
# Pagina 2, 28 productos
#
# descripcion: Setx10 Disco Abrasivo Metal 4-1/2pg x 1.2mm Makita
# marca: MAKITA
# precio final: $19.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/489568/Setx10-Disco-Abrasivo-Metal-4-1-2pg-x-12mm-Makita/489568
#
# descripcion: Taladro Atornillador de Impacto Bosch GSB 180 + 2 BaterÃ­as y Kit de Accesorios
# marca: Bosch
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $559.900UND
# precio normal internet: $749.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/329235/Taladro-Atornillador-de-Impacto-Bosch-GSB-180-2-Baterias-y-Kit-de-Accesorios/329235
#
# descripcion: Taladro Atornillador InalÃ¡mbrico 3/8-pulg BaterÃ­a 12V Dewalt
# marca: Dewalt
# precio final:
# precio normal:
# precio final CMR: $329.900UND
# precio normal CMR: $369.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/324251/Taladro-Atornillador-Inalambrico-3-8-pulg-Bateria-12V-Dewalt/324251
#
# descripcion: Taladro Percutor 1/2-pulg 800W 0-3200RPM V.V.R.
# marca: Stanley
# precio final: $289.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/275354/Taladro-Percutor-1-2-pulg-800W-0-3200RPM-VVR/275354
#
# descripcion: Kit Taladro Percutor BRUSHLESS 20V DCD778L1-B3
# marca: Dewalt
# precio final: $599.900UND
# precio normal: $699.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/502473/Kit-Taladro-Percutor-BRUSHLESS-20V-DCD778L1-B3/502473
#
# descripcion: Taladro Percutor 1/2-pulg 18V 2Ah I-L + 13 Accesorios
# marca: Bauker
# precio final: $449.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/323270/Taladro-Percutor-1-2-pulg-18V-2Ah-I-L-13-Accesorios/323270
#
# descripcion: Combo Taladro Percutor 3/8-pulg + Llave de Impacto 1/4-pulg 12V 2.0Ah Bosch
# marca: Bosch
# precio final: $659.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/490133/Combo-Taladro-Percutor-3-8-pulg-Llave-de-Impacto-1-4-pulg-12V-20Ah-Bosch/490133
#
# descripcion: Combo Taladro Percutor 1/2-pulg + Atornillador Impacto Brushless 20V Uberma
# marca: Ubermann
# precio final:
# precio normal:
# precio final CMR: $979.900UND
# precio normal CMR: $1.399.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/870005/Combo-Taladro-Percutor-1-2-pulg-Atornillador-Impacto-Brushless-20V-Uberma/870005
#
# descripcion: Taladro Percutor 1/2-pulg 710W 0-2900RPM Ubermann
# marca: Ubermann
# precio final:
# precio normal:
# precio final CMR: $269.900UND
# precio normal CMR: $299.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/490879/Taladro-Percutor-1-2-pulg-710W-0-2900RPM-Ubermann/490879
#
# descripcion: Taladro Percutor 1/2-pulg 710W 0-3200Rpm
# marca: Makita
# precio final: $257.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/346371/Taladro-Percutor-1-2-pulg-710W-0-3200Rpm/346371
#
# descripcion: Taladro 3/8Pulg Percutor 20V 2Vel
# marca: BLACK+DECKER
# precio final: $319.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/491436/Taladro-3-8Pulg-Percutor-20V-2Vel/491436
#
# descripcion: Taladro Percutor 1/2-pulg 20V Brushless
# marca: Dewalt
# precio final: $1.199.900UND
# precio normal: $1.459.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/363108/Taladro-Percutor-1-2-pulg-20V-Brushless/363108
#
# descripcion: Taladro Percutor 1/2-pulg 18V con 1 BaterÃ­a 1.5A.H y Cargador
# marca: Makita
# precio final: $399.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/412283/Taladro-Percutor-1-2-pulg-18V-con-1-Bateria-15AH-y-Cargador/412283
#
# descripcion: Taladro 1/2 Percutor 860W  0-3200Rpm
# marca: Makita
# precio final: $378.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/310126/Taladro-1-2-Percutor-860W-0-3200Rpm/310126
#
# descripcion: Taladro 1/2-pulg Percutor Atomic 20V 1.5Ah Dewalt
# marca: Dewalt
# precio final: $779.900UND
# precio normal: $899.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/505272/Taladro-1-2-pulg-Percutor-Atomic-20V-15Ah-Dewalt/505272
#
# descripcion: Taladro 1/2 Percutor 750W 3250Rpm
# marca: Bosch
# precio final: $359.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/289511/Taladro-1-2-Percutor-750W-3250Rpm/289511
#
# descripcion: Taladro 1/2-pulg Atornillador Atomic 20V 1.5Ah Dewalt
# marca: Dewalt
# precio final: $699.900UND
# precio normal: $799.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/505271/Taladro-1-2-pulg-Atornillador-Atomic-20V-15Ah-Dewalt/505271
#
# descripcion: Taladro Percutor 1/2-pulg 18V I-L 1.5Ah
# marca: Bosch
# precio final: $643.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/322090/Taladro-Percutor-1-2-pulg-18V-I-L-15Ah/322090
#
# descripcion: Taladro Percutor 3/8-pulg 12V 2.0 Ah GSB 120-LI + Caja De Herramientas Tool Box
# marca: Bosch
# precio final: $449.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/503694/Taladro-Percutor-3-8-pulg-12V-20-Ah-GSB-120-LI-Caja-De-Herramientas-Tool-Box/503694
#
# descripcion: Combo Taladro Percutor 3/8-pulg 550W + Pulidora 4-1/2 820W
# marca: BLACK+DECKER
# precio final: $214.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/402366/Combo-Taladro-Percutor-3-8-pulg-550W-Pulidora-4-1-2-820W/402366
#
# descripcion: Taladro Percutor 1/2 Pulgada 900W 2'800Rpm Vvr
# marca: Bauker
# precio final: $199.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/315724/Taladro-Percutor-1-2-Pulgada-900W-2800Rpm-Vvr/315724
#
# descripcion: Taladro InalÃ¡mbrico Atornillador 3/8-pulg 12V Ferrenovo
# marca: Ferrenovo
# precio final: $129.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/502141/Taladro-Inalambrico-Atornillador-3-8-pulg-12V-Ferrenovo/502141
#
# descripcion: Taladro de Banco 1/2-pulg 350W 760-3070RPM 5 Velocidades
# marca: Bauker
# precio final: $439.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/171449/Taladro-de-Banco-1-2-pulg-350W-760-3070RPM-5-Velocidades/171449
#
# descripcion: Taladro Percutor 1/2-pulg 20V XR Li-Ion 13Ah
# marca: Dewalt
# precio final: $839.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/265168/Taladro-Percutor-1-2-pulg-20V-XR-Li-Ion-13Ah/265168
#
# descripcion: Taladro Percutor 1/2-pulg 20V Premium
# marca: Dewalt
# precio final: $1.499.900UND
# precio normal: $1.994.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/209308/Taladro-Percutor-1-2-pulg-20V-Premium/209308
#
# descripcion: Taladro Percutor Skil 6060 1/2Pulg 700W + MaletÃ­n PlÃ¡stico y accesorio
# marca: Skil
# precio final: $209.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/496383/Taladro-Percutor-Skil-6060-1-2Pulg-700W-Maletin-Plastico-y-accesorio/496383
#
# descripcion: Taladro Percutor 1/2-pulg 18V I-L 1.5Ah
# marca: Makita
# precio final:
# precio normal:
# precio final CMR: $749.900UND
# precio normal CMR: $830.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/357574/Taladro-Percutor-1-2-pulg-18V-I-L-15Ah/357574
#
# descripcion: Taladro Percutor 3/4 pulgada 720W 2900rpm HP2050H
# marca: Makita
# precio final:
# precio normal:
# precio final CMR: $489.900UND
# precio normal CMR: $563.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/80200/Taladro-Percutor-3-4-pulgada-720W-2900rpm-HP2050H/80200
#
# Extrayendo...
# Pagina 3, 28 productos
#
# descripcion: Taladro Atornillador 3/8-pulg 12V
# marca: Milwaukee
# precio final: $799.900UND
# precio normal: $1.127.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/340738/Taladro-Atornillador-3-8-pulg-12V/340738
#
# descripcion: Taladro Percutor 1/2-pulg 18V Brushless + Brazalete
# marca: Bosch
# precio final: $799.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/511558/Taladro-Percutor-1-2-pulg-18V-Brushless-Brazalete/511558
#
# descripcion: Combo Taladro Percutor 1/2-pulg 18V + Lijadora 1/4-pulg 220W Bosch
# marca: Bosch
# precio final:
# precio normal:
# precio final CMR: $629.900UND
# precio normal CMR: $699.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/523306/Combo-Taladro-Percutor-1-2-pulg-18V-Lijadora-1-4-pulg-220W-Bosch/523306
#
# descripcion: Taladro Percutor 1/2-pulg 800W 2600RPM VVR
# marca: Dewalt
# precio final: $429.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/135697/Taladro-Percutor-1-2-pulg-800W-2600RPM-VVR/135697
#
# descripcion: Taladro Percutor 3/8-pulg 12V GSB12V-30 sin Escobillas
# marca: Bosch
# precio final: $549.900UND
# precio normal: $619.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/511556/Taladro-Percutor-3-8-pulg-12V-GSB12V-30-sin-Escobillas/511556
#
# descripcion: Combo Taladro Percutor 3/8-pulg 600W + Atornillador ElÃ©ctrico 4V
# marca: Bauker
# precio final: $149.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/361630/Combo-Taladro-Percutor-3-8-pulg-600W-Atornillador-Electrico-4V/361630
#
# descripcion: Taladro Percutor  1/2 Pulgada 700W 2900Rpm
# marca: Stanley
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $234.900UND
# precio normal internet: $269.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/300396/Taladro-Percutor-1-2-Pulgada-700W-2900Rpm/300396
#
# descripcion: Taladro Percutor Inalambrico Bosch 3/8 12V con 2 BaterÃ­as 2.0AH
# marca: Bosch
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $499.900UND
# precio normal internet: $599.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/500074/Taladro-Percutor-Inalambrico-Bosch-3-8-12V-con-2-Baterias-20AH/500074
#
# descripcion: Taladro Percutor 1/2-pulg 550W Ferrenovo
# marca: Ferrenovo
# precio final: $79.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/502142/Taladro-Percutor-1-2-pulg-550W-Ferrenovo/502142
#
# descripcion: Taladro Percutor 1/2-pulg 900W 0-3400RPM Ubermann
# marca: Ubermann
# precio final: $399.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/490876/Taladro-Percutor-1-2-pulg-900W-0-3400RPM-Ubermann/490876
#
# descripcion: Taladro Percutor 1/2Pulg + 2 BaterÃ­as + Bolso DCD778D2-B3
# marca: Dewalt
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $837.900UND
# precio normal internet: $919.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/515273/Taladro-Percutor-1-2Pulg-2-Baterias-Bolso-DCD778D2-B3/515273
#
# descripcion: Taladro Percutor 1/2 pulgada 650W 0-2.800RPM DWD024-B3
# marca: Dewalt
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $271.900UND
# precio normal internet: $319.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/09912/Taladro-Percutor-1-2-pulgada-650W-0-2800RPM-DWD024-B3/09912
#
# descripcion: Taladro Electrico De Precision Profesional
# marca: Tv Novedades
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $299.900UND
# precio normal internet: $499.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/332132/Taladro-Electrico-De-Precision-Profesional/332132
#
# descripcion: Taladro Percutor 1/2-pulg 700W 7.8A 2700Rpm V.V.R. DW505
# marca: Dewalt
# precio final: $629.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/12460/Taladro-Percutor-1-2-pulg-700W-78A-2700Rpm-VVR-DW505/12460
#
# descripcion: Taladro Percutor 3/8Pulg Profesional 500 W
# marca: Truper
# precio final: $174.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/414887/Taladro-Percutor-3-8Pulg-Profesional-500-W/414887
#
# descripcion: Taladro Percutor 1/2-pulg 550W + Juego de 13 brocas
# marca: BLACK+DECKER
# precio final: $172.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/391839/Taladro-Percutor-1-2-pulg-550W-Juego-de-13-brocas/391839
#
# descripcion: Taladro RotaciÃ³n 3/8 de-pulg 12V 1.5ah Ref GSR 120 Li
# marca: Bosch
# precio final:
# precio normal:
# precio final CMR: $439.900UND
# precio normal CMR: $559.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/287520/Taladro-Rotacion-3-8-de-pulg-12V-15ah-Ref-GSR-120-Li/287520
#
# descripcion: Taladro RotaciÃ³n 1/2-pulg 20V I-L 1.3Ah
# marca: Dewalt
# precio final: $779.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/265169/Taladro-Rotacion-1-2-pulg-20V-I-L-13Ah/265169
#
# descripcion: Taladro Percutor 3/8-pulg 12V
# marca: Milwaukee
# precio final: $999.900UND
# precio normal: $1.241.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/340739/Taladro-Percutor-3-8-pulg-12V/340739
#
# descripcion: Taladro Atornillador 3/8-pulg 400W 0-450/1400RPM 10.3NM
# marca: Bosch
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $335.900UND
# precio normal internet: $369.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/309836/Taladro-Atornillador-3-8-pulg-400W-0-450-1400RPM-103NM/309836
#
# descripcion: Taladro Percutor 1/2-pulg 20V Il+ Bateria
# marca: Stanley
# precio final: $719.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/296228/Taladro-Percutor-1-2-pulg-20V-Il-Bateria/296228
#
# descripcion: Taladro Percutor 3/8-pulg 12V I-L 1.5Ah
# marca: Makita
# precio final: $600.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/357573/Taladro-Percutor-3-8-pulg-12V-I-L-15Ah/357573
#
# descripcion: Taladro Atornillador 3/8-pulg 18V I-L 4-en-1 FlexiClick
# marca: Bosch
# precio final: $1.799.900UND
# precio normal: $2.172.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/322091/Taladro-Atornillador-3-8-pulg-18V-I-L-4-en-1-FlexiClick/322091
#
# descripcion: Taladro Percutor InalÃ¡mbrico 3/8pulg 12V DX15
# marca: Cat
# precio final: $359.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/509608/Taladro-Percutor-Inalambrico-3-8pulg-12V-DX15/509608
#
# descripcion: Taladro  Rotacion  3/8 De Pulgada  650W 2800Rpm Vvr  Ref DWD014
# marca: Dewalt
# precio final:
# precio normal:
# precio final CMR: $284.900UND
# precio normal CMR: $384.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/165908/Taladro-Rotacion-3-8-De-Pulgada-650W-2800Rpm-Vvr-Ref-DWD014/165908
#
# descripcion: Taladro de Banco 5/8-pulg 550W 210-3840RPM 16 Velocidades
# marca: Bauker
# precio final: $899.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/99561/Taladro-de-Banco-5-8-pulg-550W-210-3840RPM-16-Velocidades/99561
#
# descripcion: Taladro RotaciÃ³n 3/8-pulg 12V 1.5Ah I-L
# marca: Dewalt
# precio final:
# precio normal:
# precio final CMR: $529.900UND
# precio normal CMR: $629.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/296226/Taladro-Rotacion-3-8-pulg-12V-15Ah-I-L/296226
#
# descripcion: Taladro Percutor Electroneumatico 2 J Industrial
# marca: Truper
# precio final: $499.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/414883/Taladro-Percutor-Electroneumatico-2-J-Industrial/414883
#
# Extrayendo...
# Pagina 4, 28 productos
#
# descripcion: Taladro Percutor Skil 6604 3/8Pulg 570W con LLave de Mandril
# marca: Skil
# precio final: $159.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/496382/Taladro-Percutor-Skil-6604-3-8Pulg-570W-con-LLave-de-Mandril/496382
#
# descripcion: Taladro RotaciÃ³n Angular 3/8-pulg 12V 1.5Ah
# marca: Makita
# precio final: $629.900UND
# precio normal: $708.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/358714/Taladro-Rotacion-Angular-3-8-pulg-12V-15Ah/358714
#
# descripcion: Taladro Rotacion 1/2-pulg 20V Brushless
# marca: Dewalt
# precio final: $999.900UND
# precio normal: $1.322.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/363105/Taladro-Rotacion-1-2-pulg-20V-Brushless/363105
#
# descripcion: Taladro Industrial de Alto Torque 1/2 Pulgada 1050w
# marca: Discover Tools
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $246.900UND
# precio normal internet: $302.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336551/Taladro-Industrial-de-Alto-Torque-1-2-Pulgada-1050w/336551
#
# descripcion: Taladro Percutor 1/2-pulg 20V Sin BaterÃ­a Ubermann
# marca: Ubermann
# precio final:
# precio normal:
# precio final CMR: $729.900UND
# precio normal CMR: $899.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/487514/Taladro-Percutor-1-2-pulg-20V-Sin-Bateria-Ubermann/487514
#
# descripcion: Taladro Percutor 3/8-pulg 12V 1.5Ah I-L
# marca: Stanley
# precio final:
# precio normal:
# precio final CMR: $479.900UND
# precio normal CMR: $589.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/296225/Taladro-Percutor-3-8-pulg-12V-15Ah-I-L/296225
#
# descripcion: Taladro Percutor 1/2 Pulgada 2500rpm 810w
# marca: Discover Tools
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $170.900UND
# precio normal internet: $212.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336571/Taladro-Percutor-1-2-Pulgada-2500rpm-810w/336571
#
# descripcion: Taladro RotaciÃ³n 3/8-pulg 12V I-L 1500RPM
# marca: Stanley
# precio final:
# precio normal:
# precio final CMR: $439.900UND
# precio normal CMR: $529.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/305527/Taladro-Rotacion-3-8-pulg-12V-I-L-1500RPM/305527
#
# descripcion: Taladro Percutor 750W 1/2pulg DX17U
# marca: Cat
# precio final: $279.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/509609/Taladro-Percutor-750W-1-2pulg-DX17U/509609
#
# descripcion: Taladro de Columna 1/2 Pulgada 250W 5 Velocidades
# marca: Discover Tools
# precio final: $463.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336559/Taladro-de-Columna-1-2-Pulgada-250W-5-Velocidades/336559
#
# descripcion: Taladro de Columna 5/8 Pulgada 3/4hp 12 Velocidades
# marca: Discover Tools
# precio final: $1.421.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336561/Taladro-de-Columna-5-8-Pulgada-3-4hp-12-Velocidades/336561
#
# descripcion: Taladro RotaciÃ³n 1/2-pulg 20V 2 BaterÃ­as 2Ah Brushless Ubermann
# marca: Ubermann
# precio final:
# precio normal:
# precio final CMR: $649.900UND
# precio normal CMR: $799.900UND
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/870004/Taladro-Rotacion-1-2-pulg-20V-2-Baterias-2Ah-Brushless-Ubermann/870004
#
# descripcion: Taladro Angular 1/2-pulg 36V 5.0Ah Brushless
# marca: Makita
# precio final: $2.699.900UND
# precio normal: $3.208.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/363670/Taladro-Angular-1-2-pulg-36V-50Ah-Brushless/363670
#
# descripcion: Taladro Percutor 1/2 Pulgada 1050W 2 Velocidades TP1013
# marca: Neo
# precio final: $359.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/347078/Taladro-Percutor-1-2-Pulgada-1050W-2-Velocidades-TP1013/347078
#
# descripcion: Taladro Ãrbol 5/8 Pulgada 375W 12V
# marca: GLADIATOR
# precio final: $769.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/347077/Taladro-Arbol-5-8-Pulgada-375W-12V/347077
#
# descripcion: Kit Taladro Percutor 3/8-pulg 12V I-L + 24 Accesorios
# marca: Bosch
# precio final: $599.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/287519/Kit-Taladro-Percutor-3-8-pulg-12V-I-L-24-Accesorios/287519
#
# descripcion: Taladro 3/4Pulg 1200W Base MagnÃ©tica
# marca: Dewalt
# precio final: $7.169.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/240102/Taladro-3-4Pulg-1200W-Base-Magnetica/240102
#
# descripcion: Taladro Percutor 1/2Pulg 650 W
# marca: Truper
# precio final: $214.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/415055/Taladro-Percutor-1-2Pulg-650-W/415055
#
# descripcion: Taladro Percutor 1/2-Pulg 750W VVR
# marca: SIEFKEN
# precio final: $249.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/327599/Taladro-Percutor-1-2-Pulg-750W-VVR/327599
#
# descripcion: Taladro Percutor BRUSHLESS 1/2pulg 18V DX12
# marca: Cat
# precio final: $1.119.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/509607/Taladro-Percutor-BRUSHLESS-1-2pulg-18V-DX12/509607
#
# descripcion: Combo Taladro Percutor 1/2Pulg 600W + Pulidora 4-1/2Pulg 700W
# marca: Elite
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $249.900UND
# precio normal internet: $299.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/522782/Combo-Taladro-Percutor-1-2Pulg-600W-Pulidora-4-1-2Pulg-700W/522782
#
# descripcion: Taladro Atornillador InalÃ¡mbrico de 1/2Pulg 18V WS2938
# marca: Wesco
# precio final: $399.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/469660/Taladro-Atornillador-Inalambrico-de-1-2Pulg-18V-WS2938/469660
#
# descripcion: Taladro 3/8-pulg Percutor 12V Brushless Bosch
# marca: Bosch
# precio final: $399.900UND
# precio normal: $549.900UND
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/523642/Taladro-3-8-pulg-Percutor-12V-Brushless-Bosch/523642
#
# descripcion: Taladro Percutor 1/2-pulg 18V M18 Fuel
# marca: Milwaukee
# precio final: $2.199.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/340731/Taladro-Percutor-1-2-pulg-18V-M18-Fuel/340731
#
# descripcion: Combo Taladro RotaciÃ³n 1/2-pulg + Atornillador Impacto 18V
# marca: Makita
# precio final: $999.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/334174/Combo-Taladro-Rotacion-1-2-pulg-Atornillador-Impacto-18V/334174
#
# descripcion: Taladro sin Impacto Bosch GBM 1600 RE 850W  5/8Pulg
# marca: Bosch
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $949.900UND
# precio normal internet: $1.059.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/457652/Taladro-sin-Impacto-Bosch-GBM-1600-RE-850W-5-8Pulg/457652
#
# descripcion: Bateria XR 2Ah 20V MÃ¡x.
# marca: Dewalt
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $279.900UND
# precio normal internet: $299.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/363071/Bateria-XR-2Ah-20V-Max/363071
#
# descripcion: Taladro Atornillador Luz LED Hammersmith
# marca: Tv Novedades
# precio final: $299.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/477218/Taladro-Atornillador-Luz-LED-Hammersmith/477218
#
# Extrayendo...
# Pagina 5, 20 productos
#
# descripcion: Taladro Percutor Atornillador InalÃ¡mbrico 3/8Pulg 12V WS2547
# marca: Wesco
# precio final: $329.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/469665/Taladro-Percutor-Atornillador-Inalambrico-3-8Pulg-12V-WS2547/469665
#
# descripcion: Taladro de Columna 1-1/4 Pulgadas 1500w 12 Velocidades
# marca: Discover Tools
# precio final: $3.682.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336558/Taladro-de-Columna-1-1-4-Pulgadas-1500w-12-Velocidades/336558
#
# descripcion: Taladro Atornillador InalÃ¡mbrico 3/8Pulg - 12V WS2532
# marca: Wesco
# precio final: $264.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/469664/Taladro-Atornillador-Inalambrico-3-8Pulg-12V-WS2532/469664
#
# descripcion: Taladro Percutor 1/2 Pulgada 2800rpm 6.8amp 810w
# marca: Discover Tools
# precio final: $208.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336572/Taladro-Percutor-1-2-Pulgada-2800rpm-68amp-810w/336572
#
# descripcion: Taladro Atornillador InalÃ¡mbrico de 3/8pulg 12v
# marca: Worx
# precio final: $314.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/455764/Taladro-Atornillador-Inalambrico-de-3-8pulg-12v/455764
#
# descripcion: Taladro Percutor 1/2Pulg 750W VFR TP813
# marca: GLADIATOR
# precio final: $169.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/481960/Taladro-Percutor-1-2Pulg-750W-VFR-TP813/481960
#
# descripcion: Taladro Atornillador InalÃ¡mbrico 3/8 Pulgada 14v 2 Baterias
# marca: Discover Tools
# precio final: $426.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336552/Taladro-Atornillador-Inalambrico-3-8-Pulgada-14v-2-Baterias/336552
#
# descripcion: BaterÃ­a 20V 4Ah
# marca: Dewalt
# precio final:
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet $469.900UND
# precio normal internet: $512.900UND
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/504811/Bateria-20V-4Ah/504811
#
# descripcion: Taladro RotaciÃ³n Reversible 3/8Pulg Bosch GBM 10 RE
# marca: Bosch
# precio final: $399.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/307244/Taladro-Rotacion-Reversible-3-8Pulg-Bosch-GBM-10-RE/307244
#
# descripcion: Taladro de Columna 5/8 Pulgada 3/4hp 12 Velocidades
# marca: Discover Tools
# precio final: $1.585.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336562/Taladro-de-Columna-5-8-Pulgada-3-4hp-12-Velocidades/336562
#
# descripcion: Taladro Atornillador InalÃ¡mbrico 3/8Pulg 20V WX101 KA1
# marca: Worx
# precio final: $718.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/490927/Taladro-Atornillador-Inalambrico-3-8Pulg-20V-WX101-KA1/490927
#
# descripcion: Taladro Percutor de 750W - 1/2Pulg WS3174U
# marca: Wesco
# precio final: $179.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/469647/Taladro-Percutor-de-750W-1-2Pulg-WS3174U/469647
#
# descripcion: Taladro de Impacto 1/2 Pulgada 2.800rpm 810w
# marca: Discover Tools
# precio final: $206.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336569/Taladro-de-Impacto-1-2-Pulgada-2800rpm-810w/336569
#
# descripcion: Taladro de Columna 5/8 Pulgada 1/2hp 12 Velocidades
# marca: Discover Tools
# precio final: $1.163.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336555/Taladro-de-Columna-5-8-Pulgada-1-2hp-12-Velocidades/336555
#
# descripcion: Taladro Percutor 1/2Pulg Alto Impacto
# marca: PAMO COLOMBIA
# precio final: $202.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/473208/Taladro-Percutor-1-2Pulg-Alto-Impacto/473208
#
# descripcion: Taladro Arbol con Prensa 0.75HP - 559W 1.57M
# marca: Ktc
# precio final: $1.616.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/495862/Taladro-Arbol-con-Prensa-075HP-559W-157M/495862
#
# descripcion: Taladro de Columna 5/8 Pulgada 550w 16 Velocidades
# marca: Discover Tools
# precio final: $1.507.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336563/Taladro-de-Columna-5-8-Pulgada-550w-16-Velocidades/336563
#
# descripcion: Taladro Percutor 1/2 Pulgada 2.800rpm 780w
# marca: Discover Tools
# precio final: $239.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336570/Taladro-Percutor-1-2-Pulgada-2800rpm-780w/336570
#
# descripcion: Taladro de Impacto 1/2 Pulgada 0-2.800rpm 600w
# marca: Discover Tools
# precio final: $191.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/336567/Taladro-de-Impacto-1-2-Pulgada-0-2800rpm-600w/336567
#
# descripcion: Combo Taladro Percutor 1/2-pulg 770W + Mini Pulidora 4 1/2-pulg 700W Dewalt
# marca: Dewalt
# precio final: $489.900UND
# precio normal:
# precio final CMR:
# precio normal CMR:
# precio final internet
# precio normal internet:
# unidad: UND
# enlace: https://www.homecenter.com.co/homecenter-co/product/441394/Combo-Taladro-Percutor-1-2-pulg-770W-Mini-Pulidora-4-1-2-pulg-700W-Dewalt/441394
